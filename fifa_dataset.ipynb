# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
data = pd.read_csv("/content/players_20.csv")

# %%
data.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
data.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name   age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior  27.0  1992-02-05
# 3           J. Oblak                            Jan Oblak  26.0  1993-01-07
# 4          E. Hazard                          Eden Hazard  28.0  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0      170.0       72.0   Argentina         FC Barcelona  ...  68+2  66+2
# 1      187.0       83.0    Portugal             Juventus  ...  65+3  61+3
# 2      175.0       68.0      Brazil  Paris Saint-Germain  ...  66+3  61+3
# 3      188.0       87.0    Slovenia      Atlético Madrid  ...   NaN   NaN
# 4      175.0       74.0     Belgium          Real Madrid  ...  66+3  63+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
#
# [5 rows x 104 columns]

# %%
for col in data.columns:
  print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# mentality_aggression
# mentality_interceptions
# mentality_positioning
# mentality_vision
# mentality_penalties
# mentality_composure
# defending_marking
# defending_standing_tackle
# defending_sliding_tackle
# goalkeeping_diving
# goalkeeping_handling
# goalkeeping_kicking
# goalkeeping_positioning
# goalkeeping_reflexes
# ls
# st
# rs
# lw
# lf
# cf
# rf
# rw
# lam
# cam
# ram
# lm
# lcm
# cm
# rcm
# rm
# lwb
# ldm
# cdm
# rdm
# rwb
# lb
# lcb
# cb
# rcb
# rb

# %%
data.shape
# Out:
# (4091, 104)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4091 entries, 0 to 4090
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(60), int64(1), object(43)
# memory usage: 3.2+ MB

# %%
data.size
# Out:
# 425464

# %%
data.dtypes
# Out:
# sofifa_id       int64
# player_url     object
# short_name     object
# long_name      object
# age           float64
#                ...
# lb             object
# lcb            object
# cb             object
# rcb            object
# rb             object
# Length: 104, dtype: object

# %%
data["nationality"].value_counts()
# Out:
# Spain                   405
# Brazil                  382
# Argentina               320
# France                  286
# Germany                 223
#                        ...
# Curacao                   1
# Sierra Leone              1
# Cuba                      1
# Uzbekistan                1
# Central African Rep.      1
# Name: nationality, Length: 114, dtype: int64

# %%
data["nationality"].value_counts().head(10)
data["nationality"].value_counts()[0:10]
# Out:
# Spain          405
# Brazil         382
# Argentina      320
# France         286
# Germany        223
# England        209
# Italy          195
# Portugal       144
# Netherlands    119
# Colombia        97
# Name: nationality, dtype: int64

# %%
data["nationality"].value_counts().head(10).keys()
# Out:
# Index(['Spain', 'Brazil', 'Argentina', 'France', 'Germany', 'England', 'Italy',
#        'Portugal', 'Netherlands', 'Colombia'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
plt.bar(list(data["nationality"].value_counts().head(10).keys()),data["nationality"].value_counts().head(10),color="green")
plt.show()

# %%
player_salary = data[["short_name","wage_eur"]]

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi  565000.0
# 1  Cristiano Ronaldo  405000.0
# 2          Neymar Jr  290000.0
# 3           J. Oblak  125000.0
# 4          E. Hazard  470000.0

# %%
player_salary = player_salary.sort_values(by=["wage_eur"],ascending=False)

# %%
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 22       A. Griezmann    370000
# 5        K. De Bruyne    370000

# %%
plt.figure(figsize=(8,5))
plt.bar(list(player_salary["short_name"])[0:5],list(player_salary["wage_eur"])[0:5],color=["pink","green","yellow","red","blue"])
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.pie(list(player_salary["wage_eur"])[0:5],labels = list(player_salary["short_name"])[0:5],autopct = "%0.1f%%")
plt.show()

# %%
data[data["nationality"] == "Germany"]
# Out:
#       sofifa_id                                         player_url  \
# 6        192448  https://sofifa.com/player/192448/marc-andre-te...
# 31       167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36       182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37       188350  https://sofifa.com/player/188350/marco-reus/20...
# 49       178603  https://sofifa.com/player/178603/mats-hummels/...
# ...         ...                                                ...
# 3908     204307  https://sofifa.com/player/204307/julian-korb/2...
# 3912     204776  https://sofifa.com/player/204776/toni-leistner...
# 3937     211920  https://sofifa.com/player/211920/marco-gruttne...
# 3940     212879  https://sofifa.com/player/212879/sven-michel/2...
# 3980     222553  https://sofifa.com/player/222553/sebastian-gri...
#
#          short_name              long_name   age         dob  height_cm  \
# 6     M. ter Stegen  Marc-André ter Stegen  27.0  1992-04-30      187.0
# 31         M. Neuer           Manuel Neuer  33.0  1986-03-27      193.0
# 36         T. Kroos             Toni Kroos  29.0  1990-01-04      183.0
# 37          M. Reus             Marco Reus  30.0  1989-05-31      180.0
# 49       M. Hummels          Mats  Hummels  30.0  1988-12-16      191.0
# ...             ...                    ...   ...         ...        ...
# 3908        J. Korb            Julian Korb  27.0  1992-03-21      177.0
# 3912    T. Leistner          Toni Leistner  28.0  1990-08-19      190.0
# 3937    M. Grüttner         Marco Grüttner  33.0  1985-10-17      185.0
# 3940      S. Michel            Sven Michel  28.0  1990-07-15      179.0
# 3980   S. Griesbeck    Sebastian Griesbeck  28.0  1990-10-03      189.0
#
#       weight_kg nationality                   club  ...   lwb   ldm   cdm  \
# 6          85.0     Germany           FC Barcelona  ...   NaN   NaN   NaN
# 31         92.0     Germany      FC Bayern München  ...   NaN   NaN   NaN
# 36         76.0     Germany            Real Madrid  ...  75+3  79+3  79+3
# 37         71.0     Germany      Borussia Dortmund  ...  69+3  65+3  65+3
# 49         94.0     Germany      Borussia Dortmund  ...  77+3  83+3  83+3
# ...         ...         ...                    ...  ...   ...   ...   ...
# 3908       70.0     Germany            Hannover 96  ...  72+2  69+2  69+2
# 3912       90.0     Germany    Queens Park Rangers  ...  64+2  66+2  66+2
# 3937       84.0     Germany    SSV Jahn Regensburg  ...  51+2  51+2  51+2
# 3940       79.0     Germany        SC Paderborn 07  ...  52+2  48+2  48+2
# 3980       85.0     Germany  1. FC Heidenheim 1846  ...  67+2  70+2  70+2
#
#        rdm   rwb    lb   lcb    cb   rcb    rb
# 6      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 31     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 36    79+3  75+3  72+3  69+3  69+3  69+3  72+3
# 37    65+3  69+3  64+3  55+3  55+3  55+3  64+3
# 49    83+3  77+3  78+3  84+3  84+3  84+3  78+3
# ...    ...   ...   ...   ...   ...   ...   ...
# 3908  69+2  72+2  71+2  67+2  67+2  67+2  71+2
# 3912  66+2  64+2  66+2  71+2  71+2  71+2  66+2
# 3937  51+2  51+2  50+2  51+2  51+2  51+2  50+2
# 3940  48+2  52+2  49+2  43+2  43+2  43+2  49+2
# 3980  70+2  67+2  68+2  71+2  71+2  71+2  68+2
#
# [223 rows x 104 columns]

# %%
Germany = data[data["nationality"] == "Germany"]

# %%
Germany.head(10)
# Out:
#      sofifa_id                                         player_url  \
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 31      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...
# 49      178603  https://sofifa.com/player/178603/mats-hummels/...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 61      212622  https://sofifa.com/player/212622/joshua-kimmic...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
# 77      212190  https://sofifa.com/player/212190/niklas-sule/2...
# 109     235790  https://sofifa.com/player/235790/kai-havertz/2...
#
#         short_name              long_name   age         dob  height_cm  \
# 6    M. ter Stegen  Marc-André ter Stegen  27.0  1992-04-30      187.0
# 31        M. Neuer           Manuel Neuer  33.0  1986-03-27      193.0
# 36        T. Kroos             Toni Kroos  29.0  1990-01-04      183.0
# 37         M. Reus             Marco Reus  30.0  1989-05-31      180.0
# 49      M. Hummels          Mats  Hummels  30.0  1988-12-16      191.0
# 55         L. Sané             Leroy Sané  23.0  1996-01-11      183.0
# 61      J. Kimmich         Joshua Kimmich  24.0  1995-02-08      176.0
# 70       T. Müller          Thomas Müller  29.0  1989-09-13      186.0
# 77         N. Süle            Niklas Süle  23.0  1995-09-03      195.0
# 109     K. Havertz            Kai Havertz  20.0  1999-06-11      188.0
#
#      weight_kg nationality                 club  ...   lwb   ldm   cdm   rdm  \
# 6         85.0     Germany         FC Barcelona  ...   NaN   NaN   NaN   NaN
# 31        92.0     Germany    FC Bayern München  ...   NaN   NaN   NaN   NaN
# 36        76.0     Germany          Real Madrid  ...  75+3  79+3  79+3  79+3
# 37        71.0     Germany    Borussia Dortmund  ...  69+3  65+3  65+3  65+3
# 49        94.0     Germany    Borussia Dortmund  ...  77+3  83+3  83+3  83+3
# 55        75.0     Germany      Manchester City  ...  65+2  59+2  59+2  59+2
# 61        73.0     Germany    FC Bayern München  ...  83+3  82+3  82+3  82+3
# 70        75.0     Germany    FC Bayern München  ...  69+3  68+3  68+3  68+3
# 77        97.0     Germany    FC Bayern München  ...  71+2  77+2  77+2  77+2
# 109       83.0     Germany  Bayer 04 Leverkusen  ...  65+2  63+2  63+2  63+2
#
#       rwb    lb   lcb    cb   rcb    rb
# 6     NaN   NaN   NaN   NaN   NaN   NaN
# 31    NaN   NaN   NaN   NaN   NaN   NaN
# 36   75+3  72+3  69+3  69+3  69+3  72+3
# 37   69+3  64+3  55+3  55+3  55+3  64+3
# 49   77+3  78+3  84+3  84+3  84+3  78+3
# 55   65+2  61+2  52+2  52+2  52+2  61+2
# 61   83+3  81+3  78+3  78+3  78+3  81+3
# 70   69+3  67+3  62+3  62+3  62+3  67+3
# 77   71+2  75+2  83+2  83+2  83+2  75+2
# 109  65+2  62+2  54+2  54+2  54+2  62+2
#
# [10 rows x 104 columns]

# %%
Germany.sort_values(by=["height_cm"],ascending=False).head()
# Out:
#       sofifa_id                                         player_url  \
# 1217     200212  https://sofifa.com/player/200212/michael-esser...
# 1389     199833  https://sofifa.com/player/199833/lars-unnersta...
# 518      179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 2994     158777  https://sofifa.com/player/158777/philipp-tscha...
# 2917     194053  https://sofifa.com/player/194053/lasse-sobiech...
#
#          short_name          long_name   age         dob  height_cm  \
# 1217       M. Esser      Michael Esser  31.0  1987-11-22      198.0
# 1389  L. Unnerstall    Lars Unnerstall  28.0  1990-07-20      198.0
# 518     R. Fährmann      Ralf Fährmann  30.0  1988-09-27      197.0
# 2994   P. Tschauner  Philipp Tschauner  33.0  1985-11-03      196.0
# 2917     L. Sobiech      Lasse Sobiech  28.0  1991-01-18      196.0
#
#       weight_kg nationality          club  ...   lwb   ldm   cdm   rdm   rwb  \
# 1217       97.0     Germany   Hannover 96  ...   NaN   NaN   NaN   NaN   NaN
# 1389      103.0     Germany           PSV  ...   NaN   NaN   NaN   NaN   NaN
# 518        98.0     Germany  Norwich City  ...   NaN   NaN   NaN   NaN   NaN
# 2994       93.0     Germany    RB Leipzig  ...   NaN   NaN   NaN   NaN   NaN
# 2917       88.0     Germany    1. FC Köln  ...  60+2  64+2  64+2  64+2  60+2
#
#         lb   lcb    cb   rcb    rb
# 1217   NaN   NaN   NaN   NaN   NaN
# 1389   NaN   NaN   NaN   NaN   NaN
# 518    NaN   NaN   NaN   NaN   NaN
# 2994   NaN   NaN   NaN   NaN   NaN
# 2917  63+2  71+2  71+2  71+2  63+2
#
# [5 rows x 104 columns]

# %%
Germany.sort_values(by=["weight_kg"],ascending=False).head()
# Out:
#       sofifa_id                                         player_url  \
# 1389     199833  https://sofifa.com/player/199833/lars-unnersta...
# 518      179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1217     200212  https://sofifa.com/player/200212/michael-esser...
# 165      213331  https://sofifa.com/player/213331/jonathan-tah/...
# 77       212190  https://sofifa.com/player/212190/niklas-sule/2...
#
#          short_name        long_name   age         dob  height_cm  weight_kg  \
# 1389  L. Unnerstall  Lars Unnerstall  28.0  1990-07-20      198.0      103.0
# 518     R. Fährmann    Ralf Fährmann  30.0  1988-09-27      197.0       98.0
# 1217       M. Esser    Michael Esser  31.0  1987-11-22      198.0       97.0
# 165          J. Tah     Jonathan Tah  23.0  1996-02-11      195.0       97.0
# 77          N. Süle      Niklas Süle  23.0  1995-09-03      195.0       97.0
#
#      nationality                 club  ...   lwb   ldm   cdm   rdm   rwb  \
# 1389     Germany                  PSV  ...   NaN   NaN   NaN   NaN   NaN
# 518      Germany         Norwich City  ...   NaN   NaN   NaN   NaN   NaN
# 1217     Germany          Hannover 96  ...   NaN   NaN   NaN   NaN   NaN
# 165      Germany  Bayer 04 Leverkusen  ...  70+2  76+2  76+2  76+2  70+2
# 77       Germany    FC Bayern München  ...  71+2  77+2  77+2  77+2  71+2
#
#         lb   lcb    cb   rcb    rb
# 1389   NaN   NaN   NaN   NaN   NaN
# 518    NaN   NaN   NaN   NaN   NaN
# 1217   NaN   NaN   NaN   NaN   NaN
# 165   73+2  81+2  81+2  81+2  73+2
# 77    75+2  83+2  83+2  83+2  75+2
#
# [5 rows x 104 columns]

# %%
Germany.sort_values(by=["wage_eur"],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 146     186942  https://sofifa.com/player/186942/ilkay-gundoga...
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...
#
#         short_name              long_name   age         dob  height_cm  \
# 36        T. Kroos             Toni Kroos  29.0  1990-01-04      183.0
# 6    M. ter Stegen  Marc-André ter Stegen  27.0  1992-04-30      187.0
# 55         L. Sané             Leroy Sané  23.0  1996-01-11      183.0
# 146    I. Gündoğan         İlkay Gündoğan  28.0  1990-10-24      180.0
# 37         M. Reus             Marco Reus  30.0  1989-05-31      180.0
#
#      weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# 36        76.0     Germany        Real Madrid  ...  75+3  79+3  79+3  79+3
# 6         85.0     Germany       FC Barcelona  ...   NaN   NaN   NaN   NaN
# 55        75.0     Germany    Manchester City  ...  65+2  59+2  59+2  59+2
# 146       80.0     Germany    Manchester City  ...  76+3  79+3  79+3  79+3
# 37        71.0     Germany  Borussia Dortmund  ...  69+3  65+3  65+3  65+3
#
#       rwb    lb   lcb    cb   rcb    rb
# 36   75+3  72+3  69+3  69+3  69+3  72+3
# 6     NaN   NaN   NaN   NaN   NaN   NaN
# 55   65+2  61+2  52+2  52+2  52+2  61+2
# 146  76+3  74+3  72+3  72+3  72+3  74+3
# 37   69+3  64+3  55+3  55+3  55+3  64+3
#
# [5 rows x 104 columns]

# %%
Germany[["short_name","wage_eur"]].sort_values(by=["wage_eur"],ascending=False).head
# Out:
# <bound method NDFrame.head of          short_name  wage_eur
# 36         T. Kroos  330000.0
# 6     M. ter Stegen  250000.0
# 55          L. Sané  195000.0
# 146     I. Gündoğan  180000.0
# 37          M. Reus  170000.0
# ...             ...       ...
# 2875     J. Gressel    7000.0
# 3815   F. Jungwirth    6000.0
# 3180       O. Kragl    5000.0
# 387      B. Höwedes    1000.0
# 1536    A. Schürrle    1000.0
#
# [223 rows x 2 columns]>

# %%
#shooting

# %%
player_shooting = data[["short_name","shooting"]]

# %%
player_shooting.sort_values(by=["shooting"],ascending= False).head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
#defending

# %%
player_defending = data[["short_name","defending","nationality","club"]]

# %%
player_defending["club"].value_counts()
# Out:
# Chelsea              30
# Watford              29
# Juventus             27
# Real Madrid          27
# Manchester United    27
#                      ..
# Sunderland            1
# Górnik Zabrze         1
# Coquimbo Unido        1
# Piast Gliwice         1
# Kilmarnock            1
# Name: club, Length: 461, dtype: int64

# %%
player_defending.sort_values(by=["defending"], ascending= False).head()
# Out:
#       short_name  defending  nationality               club
# 16  G. Chiellini       90.0        Italy           Juventus
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 35      D. Godín       89.0      Uruguay              Inter
# 49    M. Hummels       89.0      Germany  Borussia Dortmund
# 11  K. Koulibaly       89.0      Senegal             Napoli

# %%
real_madrid = data[data["club"]=="Real Madrid"]

# %%
real_madrid["club"].value_counts()
# Out:
# Real Madrid    27
# Name: club, dtype: int64

# %%
real_madrid.sort_values(by=["wage_eur"],ascending=False).head()
# Out:
#     sofifa_id                                         player_url  \
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 46     165153  https://sofifa.com/player/165153/karim-benzema...
#
#       short_name            long_name   age         dob  height_cm  weight_kg  \
# 4      E. Hazard          Eden Hazard  28.0  1991-01-07      175.0       74.0
# 8      L. Modrić          Luka Modrić  33.0  1985-09-09      172.0       66.0
# 36      T. Kroos           Toni Kroos  29.0  1990-01-04      183.0       76.0
# 18  Sergio Ramos  Sergio Ramos García  33.0  1986-03-30      184.0       82.0
# 46    K. Benzema        Karim Benzema  31.0  1987-12-19      185.0       81.0
#
#    nationality         club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# 4      Belgium  Real Madrid  ...  66+3  63+3  63+3  63+3  66+3  61+3  49+3
# 8      Croatia  Real Madrid  ...  81+3  81+3  81+3  81+3  81+3  79+3  72+3
# 36     Germany  Real Madrid  ...  75+3  79+3  79+3  79+3  75+3  72+3  69+3
# 18       Spain  Real Madrid  ...  80+3  84+3  84+3  84+3  80+3  82+3  87+3
# 46      France  Real Madrid  ...  62+3  62+3  62+3  62+3  62+3  58+3  54+3
#
#       cb   rcb    rb
# 4   49+3  49+3  61+3
# 8   72+3  72+3  79+3
# 36  69+3  69+3  72+3
# 18  87+3  87+3  82+3
# 46  54+3  54+3  58+3
#
# [5 rows x 104 columns]

# %%
real_madrid.sort_values(by=["shooting"],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 100     173731  https://sofifa.com/player/173731/gareth-bale/2...
# 106     198710  https://sofifa.com/player/198710/james-rodrigu...
# 4       183277  https://sofifa.com/player/183277/eden-hazard/2...
# 46      165153  https://sofifa.com/player/165153/karim-benzema...
# 161     232432  https://sofifa.com/player/232432/luka-jovic/20...
#
#        short_name                    long_name   age         dob  height_cm  \
# 100       G. Bale            Gareth Frank Bale  29.0  1989-07-16      185.0
# 106  J. Rodríguez  James David Rodríguez Rubio  27.0  1991-07-12      180.0
# 4       E. Hazard                  Eden Hazard  28.0  1991-01-07      175.0
# 46     K. Benzema                Karim Benzema  31.0  1987-12-19      185.0
# 161      L. Jović                   Luka Jović  21.0  1997-12-23      182.0
#
#      weight_kg nationality         club  ...   lwb   ldm   cdm   rdm   rwb  \
# 100       82.0       Wales  Real Madrid  ...  72+3  69+3  69+3  69+3  72+3
# 106       75.0    Colombia  Real Madrid  ...  67+3  67+3  67+3  67+3  67+3
# 4         74.0     Belgium  Real Madrid  ...  66+3  63+3  63+3  63+3  66+3
# 46        81.0      France  Real Madrid  ...  62+3  62+3  62+3  62+3  62+3
# 161       85.0      Serbia  Real Madrid  ...  55+2  53+2  53+2  53+2  55+2
#
#        lb   lcb    cb   rcb    rb
# 100  70+3  66+3  66+3  66+3  70+3
# 106  62+3  57+3  57+3  57+3  62+3
# 4    61+3  49+3  49+3  49+3  61+3
# 46   58+3  54+3  54+3  54+3  58+3
# 161  51+2  47+2  47+2  47+2  51+2
#
# [5 rows x 104 columns]

# %%
real_madrid.sort_values(by=["defending"],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 18      155862  https://sofifa.com/player/155862/sergio-ramos-...
# 42      200145  https://sofifa.com/player/200145/carlos-henriq...
# 76      201535  https://sofifa.com/player/201535/raphael-varan...
# 94      204963  https://sofifa.com/player/204963/daniel-carvaj...
# 277     200724  https://sofifa.com/player/200724/jose-ignacio-...
#
#           short_name                          long_name   age         dob  \
# 18      Sergio Ramos                Sergio Ramos García  33.0  1986-03-30
# 42          Casemiro  Carlos Henrique Venancio Casimiro  27.0  1992-02-23
# 76         R. Varane                     Raphaël Varane  26.0  1993-04-25
# 94          Carvajal              Daniel Carvajal Ramos  27.0  1992-01-11
# 277  Nacho Fernández    José Ignacio Fernández Iglesias  29.0  1990-01-18
#
#      height_cm  weight_kg nationality         club  ...   lwb   ldm   cdm  \
# 18       184.0       82.0       Spain  Real Madrid  ...  80+3  84+3  84+3
# 42       185.0       84.0      Brazil  Real Madrid  ...  78+3  84+3  84+3
# 76       191.0       81.0      France  Real Madrid  ...  74+3  79+3  79+3
# 94       173.0       73.0       Spain  Real Madrid  ...  83+3  82+3  82+3
# 277      180.0       76.0       Spain  Real Madrid  ...  77+2  76+2  76+2
#
#       rdm   rwb    lb   lcb    cb   rcb    rb
# 18   84+3  80+3  82+3  87+3  87+3  87+3  82+3
# 42   84+3  78+3  79+3  84+3  84+3  84+3  79+3
# 76   79+3  74+3  77+3  83+3  83+3  83+3  77+3
# 94   82+3  83+3  83+3  80+3  80+3  80+3  83+3
# 277  76+2  77+2  78+2  80+2  80+2  80+2  78+2
#
# [5 rows x 104 columns]

# %%
real_madrid["nationality"].value_counts()
# Out:
# Spain                 8
# Brazil                6
# France                3
# Belgium               2
# Croatia               1
# Germany               1
# Costa Rica            1
# Wales                 1
# Colombia              1
# Serbia                1
# Dominican Republic    1
# Uruguay               1
# Name: nationality, dtype: int64
